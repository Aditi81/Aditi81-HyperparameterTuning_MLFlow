# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditi81/Aditi81-HyperparameterTuning_MLFlow/blob/master/Digit_classification_HyperparameterTuning_MLFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Outline
#
# 1.   Basic motivation of hyperparameter tuning
# 2.   Integrating Google colab with a local runtime (config in Google colab, Browser, Jupyter notebook)
# 3.   Installing MLFlow and basic use case
# 4.   Logging parameters, metrics with MLFlow
# 5.   Logging image artifacts with MLFlow
# 6.   Logging PyTorch models with MLFlow and loading them

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

import torchvision
from torchvision import datasets, transforms

import torch.nn as nn
import torch.optim as optim
import seaborn as sns

# %%
import mlflow
import mlflow.pytorch

# %% [markdown]
# # Params

# %%
class Params(object):
    def __init__(self, batch_size, epochs, seed, log_interval):
        self.batch_size = batch_size
        self.epochs = epochs
        self.seed = seed
        self.log_interval = log_interval

args = Params(256, 4, 0, 20)

# %% [markdown]
# # Dataset

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

train_set = datasets.MNIST('../data', train=True, download=True, 
                         transform=transform)

test_set = datasets.MNIST('../data', train=False, download=True, 
                         transform=transform)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=args.batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=args.batch_size, shuffle=False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/raw/train-images-idx3-ubyte.gz
# 100.1%
# Extracting ../data/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/raw/train-labels-idx1-ubyte.gz
# 113.5%
# Extracting ../data/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100.4%
# Extracting ../data/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 180.4%/pytorch/torch/csrc/utils/tensor_numpy.cpp:141: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program.
# Extracting ../data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/raw
# Processing...
# Done!

# %% [markdown]
# # Model

# %%
class Model(nn.Module):
    def __init__(self, nH): 
        super(Model, self).__init__()
        self.classifier = nn.Sequential(
            nn.Linear(784, nH),  # 28 x 28 = 784
            nn.ReLU(),
            nn.Linear(nH, 10)
        )
             
    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# %%
def train(epoch):
    
    model.train()
    
    for batch_id, data in enumerate(train_loader):
        inputs, labels = data
        
        opt.zero_grad()
        outputs = model(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        opt.step()
        
        if batch_id % args.log_interval == 0:
            pos = epoch * len(train_loader) + batch_id
            mlflow.log_metric('train_loss', loss.data.item()/len(inputs)*1000)
            
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.3f}'.format(
                epoch, batch_id * len(inputs), len(train_loader.dataset),
                100. * batch_id / len(train_loader), loss.data.item()))

# %%
def test(epoch):
    
    model.eval()
    test_loss = 0
    correct = 0
    confusion_matrix = np.zeros([10, 10])
    
    with torch.no_grad():
        
        for inputs, labels in test_loader:
            outputs = model(inputs)
            test_loss += loss_fn(outputs, labels).data.item()
            pred = outputs.data.max(1)[1]
            correct += pred.eq(labels.data).sum().item()
            
            for x, y in zip(pred.numpy(), labels.numpy()):
                confusion_matrix[x][y] += 1
            
        test_loss /= len(test_loader.dataset)
        test_accuracy = 100.0 * correct / len(test_loader.dataset)
        
        pos = (epoch + 1) * len(train_loader)
        mlflow.log_metric('test_loss', test_loss*1000)
        mlflow.log_metric('test_accuracy', test_accuracy)
        
        print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.
              format(test_loss, correct, len(test_loader.dataset), test_accuracy))
              
        if epoch == args.epochs:
            classes = np.arange(10)
            fig, ax = plt.subplots()
            im = ax.imshow(confusion_matrix, interpolation='nearest', cmap=plt.cm.Blues)
            ax.figure.colorbar(im, ax=ax)
            ax.set(xticks=np.arange(confusion_matrix.shape[1]),
                       yticks=np.arange(confusion_matrix.shape[0]),
                       xticklabels=classes, yticklabels=classes,
                       ylabel='True label',
                       xlabel='Predicted label',
                       title='Epoch %d' % epoch)
            thresh = confusion_matrix.max() / 2.
            for i in range(confusion_matrix.shape[0]):
                for j in range(confusion_matrix.shape[1]):
                    ax.text(j, i, int(confusion_matrix[i, j]),
                            ha="center", va="center",
                            color="white" if confusion_matrix[i, j] > thresh else "black")
              
            fig.tight_layout()
              
            image_path = 'images/%s.png' % (expt_id)
            plt.savefig(image_path)
            mlflow.log_artifact(image_path)

# %% [markdown]
# # Hyperparameter tuning loop

# %%
# expt_id = mlflow.create_experiment('Fixed nH')

# mlflow.set_experiment('Fixed nH')

for lr in [0.01]:
    for momentum in [0.9]:
        for hidden_nodes in [16, 32, 48]:
        
            expt_id = '%d_%d_%d' % (int(lr*100), int(momentum*100), hidden_nodes)
, 0.02, 0.05, 0.1 , 0.95, 0.99
            print('\nLR = %.2f, Momentum = %.2f, Hidden nodes = %d\n' % (lr, momentum, hidden_nodes))

            model = Model(hidden_nodes)

            loss_fn = nn.CrossEntropyLoss()
            opt = optim.SGD(model.parameters(), lr=lr, momentum = momentum)

            with mlflow.start_run() as run:  
                for key, value in vars(args).items():
                    mlflow.log_param(key, value)
                mlflow.log_param('lr', lr)
                mlflow.log_param('momentum', momentum)
                mlflow.log_param('hidden_nodes', hidden_nodes)

                for epoch in range(1, args.epochs + 1):
                    train(epoch)
                    test(epoch)

                mlflow.pytorch.log_model(model, "models")
# Out:
# LR = 0.01, Momentum = 0.90, Hidden nodes = 16
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.272
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 1.458
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.542
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.461
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.325
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.424
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.402
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.300
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.381
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.278
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.212
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.237
#
# Test set: Average loss: 0.0012, Accuracy: 9200/10000 (92%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.298
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.251
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.245
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.281
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.340
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.189
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.280
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.377
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.279
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.287
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.357
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.225
#
# Test set: Average loss: 0.0010, Accuracy: 9269/10000 (93%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.248
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.214
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.265
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.379
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.338
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.193
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.227
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.289
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.201
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.254
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.245
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.195
#
# Test set: Average loss: 0.0009, Accuracy: 9355/10000 (94%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.216
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.189
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.232
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.208
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.193
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.198
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.256
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.158
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.208
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.232
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.189
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.172
#
# Test set: Average loss: 0.0008, Accuracy: 9405/10000 (94%)
#
#
# LR = 0.01, Momentum = 0.90, Hidden nodes = 32
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.327
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 1.020
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.465
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.543
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.433
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.319
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.344
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.326
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.278
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.292
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.252
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.351
#
# Test set: Average loss: 0.0011, Accuracy: 9226/10000 (92%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.255
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.341
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.227
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.226
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.281
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.279
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.225
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.360
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.234
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.261
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.246
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.280
#
# Test set: Average loss: 0.0009, Accuracy: 9345/10000 (93%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.268
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.166
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.208
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.212
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.234
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.155
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.198
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.160
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.254
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.187
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.205
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.170
#
# Test set: Average loss: 0.0008, Accuracy: 9437/10000 (94%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.152
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.285
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.163
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.229
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.222
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.168
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.228
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.125
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.146
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.137
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.212
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.208
#
# Test set: Average loss: 0.0007, Accuracy: 9481/10000 (95%)
#
#
# LR = 0.01, Momentum = 0.90, Hidden nodes = 48
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.351
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 1.127
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.600
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.430
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.429
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.291
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.475
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.266
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.285
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.269
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.408
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.245
#
# Test set: Average loss: 0.0011, Accuracy: 9203/10000 (92%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.236
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.262
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.204
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.270
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.203
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.216
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.247
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.261
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.292
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.183
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.203
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.262
#
# Test set: Average loss: 0.0008, Accuracy: 9386/10000 (94%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.168
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.199
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.274
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.251
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.158
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.195
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.170
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.231
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.277
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.270
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.267
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.208
#
# Test set: Average loss: 0.0007, Accuracy: 9470/10000 (95%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.182
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.111
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.215
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.191
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.195
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.127
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.184
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.125
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.176
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.140
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.118
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.203
#
# Test set: Average loss: 0.0006, Accuracy: 9549/10000 (95%)
#
#
# LR = 0.01, Momentum = 0.95, Hidden nodes = 16
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.312
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.965
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.557
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.347
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.548
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.371
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.482
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.236
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.353
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.235
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.349
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.233
#
# Test set: Average loss: 0.0011, Accuracy: 9171/10000 (92%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.239
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.278
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.309
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.235
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.220
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.291
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.283
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.281
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.259
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.237
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.252
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.243
#
# Test set: Average loss: 0.0009, Accuracy: 9307/10000 (93%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.160
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.187
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.227
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.206
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.267
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.207
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.253
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.299
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.373
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.235
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.179
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.201
#
# Test set: Average loss: 0.0008, Accuracy: 9382/10000 (94%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.137
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.230
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.151
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.178
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.195
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.155
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.262
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.168
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.190
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.162
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.147
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.140
#
# Test set: Average loss: 0.0008, Accuracy: 9422/10000 (94%)
#
#
# LR = 0.01, Momentum = 0.95, Hidden nodes = 32
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.348
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.908
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.439
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.417
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.339
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.369
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.316
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.307
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.335
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.297
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.302
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.234
#
# Test set: Average loss: 0.0010, Accuracy: 9260/10000 (93%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.220
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.260
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.226
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.281
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.245
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.216
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.240
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.273
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.236
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.241
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.181
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.279
#
# Test set: Average loss: 0.0007, Accuracy: 9445/10000 (94%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.200
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.160
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.182
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.136
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.199
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.195
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.164
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.156
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.140
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.108
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.129
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.145
#
# Test set: Average loss: 0.0007, Accuracy: 9492/10000 (95%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.101
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.266
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.160
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.164
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.161
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.180
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.117
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.116
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.125
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.126
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.143
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.186
#
# Test set: Average loss: 0.0006, Accuracy: 9550/10000 (96%)
#
#
# LR = 0.01, Momentum = 0.95, Hidden nodes = 48
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.319
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.713
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.515
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.416
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.454
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.341
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.315
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.269
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.261
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.332
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.229
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.227
#
# Test set: Average loss: 0.0009, Accuracy: 9306/10000 (93%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.144
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.236
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.299
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.236
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.246
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.217
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.137
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.199
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.216
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.150
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.146
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.175
#
# Test set: Average loss: 0.0007, Accuracy: 9471/10000 (95%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.186
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.110
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.159
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.128
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.132
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.133
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.194
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.157
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.143
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.132
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.171
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.128
#
# Test set: Average loss: 0.0006, Accuracy: 9583/10000 (96%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.089
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.115
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.121
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.133
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.186
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.085
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.150
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.145
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.169
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.097
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.158
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.124
#
# Test set: Average loss: 0.0005, Accuracy: 9619/10000 (96%)
#
#
# LR = 0.01, Momentum = 0.99, Hidden nodes = 16
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.335
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.987
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.840
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.952
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.759
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.702
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.743
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.506
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.545
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.394
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.523
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.601
#
# Test set: Average loss: 0.0019, Accuracy: 8742/10000 (87%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.353
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.440
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.462
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.459
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.390
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.313
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.302
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.433
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.286
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.278
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.268
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.404
#
# Test set: Average loss: 0.0011, Accuracy: 9223/10000 (92%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.311
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.244
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.207
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.322
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.271
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.136
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.240
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.216
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.310
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.204
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.314
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.225
#
# Test set: Average loss: 0.0011, Accuracy: 9273/10000 (93%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.269
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.135
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.340
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.273
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.211
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.274
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.251
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.332
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.283
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.209
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.164
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.176
#
# Test set: Average loss: 0.0009, Accuracy: 9332/10000 (93%)
#
#
# LR = 0.01, Momentum = 0.99, Hidden nodes = 32
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.341
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.760
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.758
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.998
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 1.245
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.953
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.611
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.611
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.738
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.712
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.408
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.486
#
# Test set: Average loss: 0.0017, Accuracy: 8976/10000 (90%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.346
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.378
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.467
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.405
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.422
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.168
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.398
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.223
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.277
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.301
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.311
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.394
#
# Test set: Average loss: 0.0011, Accuracy: 9251/10000 (93%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.472
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.283
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.264
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.240
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.212
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.307
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.270
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.336
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.159
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.197
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.135
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.198
#
# Test set: Average loss: 0.0008, Accuracy: 9405/10000 (94%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.203
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.210
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.134
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.246
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.098
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.187
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.147
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.125
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.143
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.259
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.315
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.244
#
# Test set: Average loss: 0.0007, Accuracy: 9469/10000 (95%)
#
#
# LR = 0.01, Momentum = 0.99, Hidden nodes = 48
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.330
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.804
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.684
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.829
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.881
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.875
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.596
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.492
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.469
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.442
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.351
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.207
#
# Test set: Average loss: 0.0013, Accuracy: 9084/10000 (91%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.388
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.323
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.365
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.305
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.207
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.376
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.180
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.247
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.258
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.216
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.281
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.210
#
# Test set: Average loss: 0.0008, Accuracy: 9405/10000 (94%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.161
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.155
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.111
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.111
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.191
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.151
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.139
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.142
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.200
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.216
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.134
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.143
#
# Test set: Average loss: 0.0006, Accuracy: 9561/10000 (96%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.101
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.107
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.170
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.146
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.145
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.153
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.150
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.157
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.207
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.066
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.154
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.083
#
# Test set: Average loss: 0.0005, Accuracy: 9611/10000 (96%)
#
#
# LR = 0.02, Momentum = 0.90, Hidden nodes = 16
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.331
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.859
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.514
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.394
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.368
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.355
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.339
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.337
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.333
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.274
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.251
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.261
#
# Test set: Average loss: 0.0010, Accuracy: 9280/10000 (93%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.281
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.261
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.196
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.228
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.297
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.216
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.271
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.328
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.238
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.189
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.140
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.150
#
# Test set: Average loss: 0.0009, Accuracy: 9351/10000 (94%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.260
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.167
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.174
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.196
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.216
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.203
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.231
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.157
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.227
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.180
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.269
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.183
#
# Test set: Average loss: 0.0008, Accuracy: 9401/10000 (94%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.229
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.124
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.162
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.223
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.190
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.210
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.145
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.206
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.111
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.207
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.151
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.237
#
# Test set: Average loss: 0.0007, Accuracy: 9437/10000 (94%)
#
#
# LR = 0.02, Momentum = 0.90, Hidden nodes = 32
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.304
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.619
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.569
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.387
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.287
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.270
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.348
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.180
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.315
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.266
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.210
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.235
#
# Test set: Average loss: 0.0009, Accuracy: 9331/10000 (93%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.211
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.281
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.195
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.128
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.158
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.273
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.141
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.166
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.206
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.162
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.163
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.113
#
# Test set: Average loss: 0.0007, Accuracy: 9488/10000 (95%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.119
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.160
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.169
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.144
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.211
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.216
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.082
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.155
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.124
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.110
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.117
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.141
#
# Test set: Average loss: 0.0006, Accuracy: 9556/10000 (96%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.141
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.132
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.126
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.097
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.103
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.099
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.076
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.085
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.121
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.078
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.064
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.095
#
# Test set: Average loss: 0.0005, Accuracy: 9615/10000 (96%)
#
#
# LR = 0.02, Momentum = 0.90, Hidden nodes = 48
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.292
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.691
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.393
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.389
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.317
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.418
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.285
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.180
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.220
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.259
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.281
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.214
#
# Test set: Average loss: 0.0008, Accuracy: 9386/10000 (94%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.258
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.169
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.294
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.140
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.111
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.184
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.232
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.126
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.119
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.125
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.135
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.175
#
# Test set: Average loss: 0.0006, Accuracy: 9522/10000 (95%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.164
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.173
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.217
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.177
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.166
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.122
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.133
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.156
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.155
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.133
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.110
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.078
#
# Test set: Average loss: 0.0005, Accuracy: 9626/10000 (96%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.089
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.049
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.136
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.112
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.150
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.167
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.054
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.107
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.127
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.109
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.128
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.113
#
# Test set: Average loss: 0.0005, Accuracy: 9658/10000 (97%)
#
#
# LR = 0.02, Momentum = 0.95, Hidden nodes = 16
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.360
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.695
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.356
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.646
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.481
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.360
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.351
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.229
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.249
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.240
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.279
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.305
#
# Test set: Average loss: 0.0009, Accuracy: 9269/10000 (93%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.198
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.206
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.282
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.251
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.295
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.206
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.264
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.218
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.231
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.229
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.178
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.216
#
# Test set: Average loss: 0.0008, Accuracy: 9419/10000 (94%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.210
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.182
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.223
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.126
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.134
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.131
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.157
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.217
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.232
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.147
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.123
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.147
#
# Test set: Average loss: 0.0007, Accuracy: 9469/10000 (95%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.169
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.162
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.135
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.116
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.187
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.288
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.122
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.275
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.257
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.160
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.251
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.184
#
# Test set: Average loss: 0.0007, Accuracy: 9501/10000 (95%)
#
#
# LR = 0.02, Momentum = 0.95, Hidden nodes = 32
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.364
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.492
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.389
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.475
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.376
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.264
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.289
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.285
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.311
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.231
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.289
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.284
#
# Test set: Average loss: 0.0008, Accuracy: 9372/10000 (94%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.159
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.211
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.136
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.190
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.148
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.112
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.208
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.104
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.133
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.199
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.146
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.236
#
# Test set: Average loss: 0.0006, Accuracy: 9516/10000 (95%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.154
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.092
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.167
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.066
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.163
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.145
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.094
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.179
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.177
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.163
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.100
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.156
#
# Test set: Average loss: 0.0006, Accuracy: 9554/10000 (96%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.100
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.087
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.081
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.121
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.157
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.125
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.164
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.126
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.082
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.122
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.198
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.066
#
# Test set: Average loss: 0.0005, Accuracy: 9612/10000 (96%)
#
#
# LR = 0.02, Momentum = 0.95, Hidden nodes = 48
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.323
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.559
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.273
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.382
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.443
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.288
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.220
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.203
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.225
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.196
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.196
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.125
#
# Test set: Average loss: 0.0008, Accuracy: 9377/10000 (94%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.137
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.159
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.138
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.118
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.212
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.150
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.237
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.134
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.155
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.120
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.126
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.190
#
# Test set: Average loss: 0.0005, Accuracy: 9626/10000 (96%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.104
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.108
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.093
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.063
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.126
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.119
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.171
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.097
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.120
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.078
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.100
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.091
#
# Test set: Average loss: 0.0004, Accuracy: 9639/10000 (96%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.062
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.089
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.081
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.087
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.112
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.044
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.107
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.111
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.064
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.097
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.096
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.075
#
# Test set: Average loss: 0.0004, Accuracy: 9660/10000 (97%)
#
#
# LR = 0.02, Momentum = 0.99, Hidden nodes = 16
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.340
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.835
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.714
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.812
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.877
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.776
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.941
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.806
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.887
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.868
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.750
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.659
#
# Test set: Average loss: 0.0027, Accuracy: 8413/10000 (84%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.865
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.534
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.565
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.379
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.533
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.637
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.539
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.408
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.426
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.231
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.404
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.526
#
# Test set: Average loss: 0.0017, Accuracy: 8930/10000 (89%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.357
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.399
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.518
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.237
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.329
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.437
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.494
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.382
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.384
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.240
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.323
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.373
#
# Test set: Average loss: 0.0013, Accuracy: 9163/10000 (92%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.443
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.312
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.348
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.350
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.365
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.231
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.396
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.328
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.252
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.528
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.280
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.300
#
# Test set: Average loss: 0.0015, Accuracy: 9098/10000 (91%)
#
#
# LR = 0.02, Momentum = 0.99, Hidden nodes = 32
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.284
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.598
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 1.240
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.874
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.736
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.727
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.632
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.651
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.529
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.512
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.450
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.341
#
# Test set: Average loss: 0.0017, Accuracy: 8863/10000 (89%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.385
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.462
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.469
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.518
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.404
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.489
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.309
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.432
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.365
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.264
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.341
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.185
#
# Test set: Average loss: 0.0012, Accuracy: 9203/10000 (92%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.209
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.268
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.210
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.388
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.321
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.202
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.256
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.447
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.361
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.401
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.291
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.202
#
# Test set: Average loss: 0.0011, Accuracy: 9292/10000 (93%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.177
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.244
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.202
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.222
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.304
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.242
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.218
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.374
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.257
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.254
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.245
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.261
#
# Test set: Average loss: 0.0010, Accuracy: 9374/10000 (94%)
#
#
# LR = 0.02, Momentum = 0.99, Hidden nodes = 48
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.333
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.577
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 1.052
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.586
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.823
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.878
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.637
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.608
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.562
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.732
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.726
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.587
#
# Test set: Average loss: 0.0020, Accuracy: 8664/10000 (87%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.632
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.635
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.465
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.500
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.376
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.241
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.484
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.393
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.328
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.368
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.340
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.425
#
# Test set: Average loss: 0.0013, Accuracy: 9214/10000 (92%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.184
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.234
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.255
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.254
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.230
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.322
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.395
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.228
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.225
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.232
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.274
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.255
#
# Test set: Average loss: 0.0011, Accuracy: 9254/10000 (93%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.306
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.233
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.223
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.342
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.371
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.232
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.179
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.164
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.280
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.242
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.226
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.154
#
# Test set: Average loss: 0.0010, Accuracy: 9391/10000 (94%)
#
#
# LR = 0.05, Momentum = 0.90, Hidden nodes = 16
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.326
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.597
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.258
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.347
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.309
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.299
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.293
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.389
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.225
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.255
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.274
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.325
#
# Test set: Average loss: 0.0009, Accuracy: 9328/10000 (93%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.296
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.235
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.180
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.150
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.309
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.200
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.299
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.223
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.192
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.248
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.162
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.255
#
# Test set: Average loss: 0.0008, Accuracy: 9412/10000 (94%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.286
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.214
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.166
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.290
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.163
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.202
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.256
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.121
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.087
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.186
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.220
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.248
#
# Test set: Average loss: 0.0007, Accuracy: 9462/10000 (95%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.099
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.087
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.133
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.152
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.174
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.112
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.173
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.138
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.175
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.121
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.168
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.129
#
# Test set: Average loss: 0.0007, Accuracy: 9430/10000 (94%)
#
#
# LR = 0.05, Momentum = 0.90, Hidden nodes = 32
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.322
# ...
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.075
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.099
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.077
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.096
#
# Test set: Average loss: 0.0005, Accuracy: 9650/10000 (96%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.074
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.069
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.048
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.052
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.057
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.154
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.060
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.084
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.095
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.095
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.050
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.104
#
# Test set: Average loss: 0.0005, Accuracy: 9632/10000 (96%)
#
#
# LR = 0.10, Momentum = 0.95, Hidden nodes = 16
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.343
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.938
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.678
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.533
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.495
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.444
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.527
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.393
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.351
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.428
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.388
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.393
#
# Test set: Average loss: 0.0011, Accuracy: 9158/10000 (92%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.284
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.320
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.227
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.315
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.351
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.198
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.230
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.308
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.349
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.320
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.393
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.213
#
# Test set: Average loss: 0.0011, Accuracy: 9264/10000 (93%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.214
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.346
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.244
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.220
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.158
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.388
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.315
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.436
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.150
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.259
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.141
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.388
#
# Test set: Average loss: 0.0010, Accuracy: 9305/10000 (93%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.185
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.223
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.225
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.388
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.212
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.171
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.328
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.268
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.398
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.173
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.373
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.336
#
# Test set: Average loss: 0.0011, Accuracy: 9307/10000 (93%)
#
#
# LR = 0.10, Momentum = 0.95, Hidden nodes = 32
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.328
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 1.042
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.580
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.584
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.301
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.428
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.397
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.310
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.281
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.208
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.255
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.339
#
# Test set: Average loss: 0.0010, Accuracy: 9273/10000 (93%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.272
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.204
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.244
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.149
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.187
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.266
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.234
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.312
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.430
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.199
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.217
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.316
#
# Test set: Average loss: 0.0010, Accuracy: 9336/10000 (93%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.198
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.159
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.445
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.170
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.249
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.150
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.229
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.354
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.181
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.242
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.068
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.199
#
# Test set: Average loss: 0.0008, Accuracy: 9419/10000 (94%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.182
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.288
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.183
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.293
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.222
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.198
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.213
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.151
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.154
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.168
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.185
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.108
#
# Test set: Average loss: 0.0007, Accuracy: 9497/10000 (95%)
#
#
# LR = 0.10, Momentum = 0.95, Hidden nodes = 48
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.340
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 1.356
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.530
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 0.435
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 0.416
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.412
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 0.362
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 0.198
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 0.197
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 0.307
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.212
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 0.230
#
# Test set: Average loss: 0.0011, Accuracy: 9215/10000 (92%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.222
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.149
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 0.280
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 0.199
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 0.204
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.410
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 0.227
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 0.293
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 0.192
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 0.155
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.273
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 0.280
#
# Test set: Average loss: 0.0008, Accuracy: 9375/10000 (94%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.251
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 0.180
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 0.176
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 0.220
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 0.169
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.227
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 0.133
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 0.113
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 0.198
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 0.124
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.079
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 0.080
#
# Test set: Average loss: 0.0007, Accuracy: 9488/10000 (95%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.195
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 0.119
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 0.120
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 0.111
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 0.163
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.106
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 0.125
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 0.248
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 0.137
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 0.175
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.069
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 0.165
#
# Test set: Average loss: 0.0007, Accuracy: 9493/10000 (95%)
#
#
# LR = 0.10, Momentum = 0.99, Hidden nodes = 16
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.402
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 1.698
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 1.025
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 1.029
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 1.529
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 2.595
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 1.357
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 1.860
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 1.283
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 1.321
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 1.410
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 1.417
#
# Test set: Average loss: 0.0051, Accuracy: 5737/10000 (57%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 1.214
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 1.490
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 1.087
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 1.315
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 1.474
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 2.263
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 1.375
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 1.903
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 1.762
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 1.849
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 1.448
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 1.563
#
# Test set: Average loss: 0.0062, Accuracy: 4769/10000 (48%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 1.300
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 1.320
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 1.619
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 1.691
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 1.791
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 1.812
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 1.660
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 1.571
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 1.623
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 2.052
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 1.884
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 1.871
#
# Test set: Average loss: 0.0082, Accuracy: 2469/10000 (25%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 1.991
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 2.045
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 1.861
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 2.015
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 1.928
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 1.956
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 1.986
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 1.975
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 2.000
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 1.984
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 1.985
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 1.921
#
# Test set: Average loss: 0.0081, Accuracy: 2449/10000 (24%)
#
#
# LR = 0.10, Momentum = 0.99, Hidden nodes = 32
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.296
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 2.025
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 1.142
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 1.084
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 1.295
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 1.408
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 1.366
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 1.693
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 1.650
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 1.221
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 1.471
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 1.557
#
# Test set: Average loss: 0.0056, Accuracy: 6239/10000 (62%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 1.676
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 1.315
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 1.105
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 1.252
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 1.277
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 1.356
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 1.479
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 1.149
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 1.221
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 1.366
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 1.501
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 1.423
#
# Test set: Average loss: 0.0065, Accuracy: 5596/10000 (56%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 1.300
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 1.302
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 1.264
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 1.256
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 1.286
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 1.486
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 1.162
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 1.419
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 1.369
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 1.341
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 1.402
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 1.490
#
# Test set: Average loss: 0.0057, Accuracy: 5133/10000 (51%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 1.381
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 1.654
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 1.213
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 1.371
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 1.150
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 1.387
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 1.609
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 1.630
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 1.611
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 1.690
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 1.681
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 1.761
#
# Test set: Average loss: 0.0073, Accuracy: 3771/10000 (38%)
#
#
# LR = 0.10, Momentum = 0.99, Hidden nodes = 48
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.326
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 1.877
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 1.062
# Train Epoch: 1 [15360/60000 (26%)]	Loss: 1.688
# Train Epoch: 1 [20480/60000 (34%)]	Loss: 1.361
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 1.581
# Train Epoch: 1 [30720/60000 (51%)]	Loss: 1.297
# Train Epoch: 1 [35840/60000 (60%)]	Loss: 2.293
# Train Epoch: 1 [40960/60000 (68%)]	Loss: 1.549
# Train Epoch: 1 [46080/60000 (77%)]	Loss: 1.560
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 1.321
# Train Epoch: 1 [56320/60000 (94%)]	Loss: 1.126
#
# Test set: Average loss: 0.0056, Accuracy: 5601/10000 (56%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 1.699
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 1.428
# Train Epoch: 2 [10240/60000 (17%)]	Loss: 1.434
# Train Epoch: 2 [15360/60000 (26%)]	Loss: 1.324
# Train Epoch: 2 [20480/60000 (34%)]	Loss: 1.127
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 1.600
# Train Epoch: 2 [30720/60000 (51%)]	Loss: 1.620
# Train Epoch: 2 [35840/60000 (60%)]	Loss: 1.539
# Train Epoch: 2 [40960/60000 (68%)]	Loss: 1.469
# Train Epoch: 2 [46080/60000 (77%)]	Loss: 1.787
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 1.688
# Train Epoch: 2 [56320/60000 (94%)]	Loss: 1.247
#
# Test set: Average loss: 0.0063, Accuracy: 4786/10000 (48%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 1.402
# Train Epoch: 3 [5120/60000 (9%)]	Loss: 1.357
# Train Epoch: 3 [10240/60000 (17%)]	Loss: 1.330
# Train Epoch: 3 [15360/60000 (26%)]	Loss: 1.380
# Train Epoch: 3 [20480/60000 (34%)]	Loss: 1.406
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 1.999
# Train Epoch: 3 [30720/60000 (51%)]	Loss: 1.510
# Train Epoch: 3 [35840/60000 (60%)]	Loss: 1.387
# Train Epoch: 3 [40960/60000 (68%)]	Loss: 1.458
# Train Epoch: 3 [46080/60000 (77%)]	Loss: 1.497
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 1.510
# Train Epoch: 3 [56320/60000 (94%)]	Loss: 1.521
#
# Test set: Average loss: 0.0060, Accuracy: 4395/10000 (44%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 1.380
# Train Epoch: 4 [5120/60000 (9%)]	Loss: 1.441
# Train Epoch: 4 [10240/60000 (17%)]	Loss: 1.306
# Train Epoch: 4 [15360/60000 (26%)]	Loss: 1.471
# Train Epoch: 4 [20480/60000 (34%)]	Loss: 1.377
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 1.457
# Train Epoch: 4 [30720/60000 (51%)]	Loss: 1.356
# Train Epoch: 4 [35840/60000 (60%)]	Loss: 1.405
# Train Epoch: 4 [40960/60000 (68%)]	Loss: 1.460
# Train Epoch: 4 [46080/60000 (77%)]	Loss: 1.401
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 1.298
# Train Epoch: 4 [56320/60000 (94%)]	Loss: 1.427
#
# Test set: Average loss: 0.0061, Accuracy: 4806/10000 (48%)

# %% [markdown]
# # Loading and visualising a model

# %%
model_load = mlflow.pytorch.load_model('models', run_id="9a5e902876654a88b9876e481aa37b27")

# %%
print(model_load)
# Out:
# Model(
#   (classifier): Sequential(
#     (0): Linear(in_features=784, out_features=48, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=48, out_features=10, bias=True)
#   )
# )

# %%
weight_layer0 = list(model_load.parameters())[0].data.numpy()

# %%
print(weight_layer0.shape)
# Out:
# (48, 784)

# %%
sns.distplot(weight_layer0.ravel())
plt.plot()
# Out:
# []

# %%
sns.heatmap(np.abs(weight_layer0))
plt.show()

# %%
weight_layer1 = list(model_load.parameters())[2].data.numpy()

# %%
weight_layer1.shape
# Out:
# (10, 48)

# %%
sns.distplot(weight_layer1.ravel())
plt.plot()
# Out:
# []

# %%
sns.heatmap(np.abs(weight_layer1))
plt.show()

# %%
nrows = 6
ncols = 8
fig = plt.figure(figsize=(1.5*ncols, 1.5*nrows))

for i in np.arange(48): 
    ax1 = fig.add_subplot(nrows, ncols, i+1)
    sns.heatmap(np.abs((weight_layer0[i, 0:784]).reshape(28, 28)), ax = ax1, cbar=False)
    ax1.axis('off')
    ax1.set_xticklabels([])
    ax1.set_yticklabels([])
    ax1.set_title(i)
plt.tight_layout()
plt.show()
